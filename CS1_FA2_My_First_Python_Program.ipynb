# %% [markdown]
# <a href="https://colab.research.google.com/github/JON-030814/cs1-python-EMERALD-MAQUIDATO/blob/main/CS1_FA2_My_First_Python_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

if (num1 >= num2) and (num1 >= num3):
  print("The biggest number is:", num1)
elif (num2 >= num1) and (num2 >= num3):
  print("The biggest number is: ", num2)
else:
  print("The biggest number is: ", num3)
